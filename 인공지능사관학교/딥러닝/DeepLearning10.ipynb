# %%
# %run /content/abalone_model.ipynb
# %run /content/MathUtils.ipynb
# Out:
# ERROR:root:File `'/content/CopyMathUtilis.ipynb.py'` not found.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
main_execute(10,32,1,0.8)
# Out:
# Epoch 1 : Train - Loss = 8.964, Accuracy = 0.792  / Test - Accuracy = 0.805
# Epoch 2 : Train - Loss = 6.876, Accuracy = 0.805  / Test - Accuracy = 0.796
# Epoch 3 : Train - Loss = 6.746, Accuracy = 0.806  / Test - Accuracy = 0.799
# Epoch 4 : Train - Loss = 6.549, Accuracy = 0.808  / Test - Accuracy = 0.815
# Epoch 5 : Train - Loss = 6.373, Accuracy = 0.812  / Test - Accuracy = 0.822
# Epoch 6 : Train - Loss = 6.231, Accuracy = 0.815  / Test - Accuracy = 0.813
# Epoch 7 : Train - Loss = 6.109, Accuracy = 0.817  / Test - Accuracy = 0.826
# Epoch 8 : Train - Loss = 5.977, Accuracy = 0.819  / Test - Accuracy = 0.805
# Epoch 9 : Train - Loss = 5.874, Accuracy = 0.820  / Test - Accuracy = 0.815
# Epoch 10 : Train - Loss = 5.782, Accuracy = 0.822  / Test - Accuracy = 0.828
# =================================== Final TEST ===================================
#
# Final Accuracy : 0.828
# ([array([[ 0.37444686],
#          [ 0.02774146],
#          [ 0.01266975],
#          [ 3.69409606],
# ...
