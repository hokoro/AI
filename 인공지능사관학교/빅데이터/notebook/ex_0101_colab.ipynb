# %% [markdown]
# ### SQLite 데이터 베이스 Python으로 접속

# %%
import sqlite3
import os

# %%
from google.colab import drive
# 구글 드라이브 마운트.
drive.mount('/content/drive')  # 절차를 따라서 한다
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/인공지능사관학교/빅데이터/notebook/ #! command 가 아닌 %command 로 들어간다
#리눅스 환경은 / 로 파일 이동을 해야 한다.
# Out:
# /content/drive/MyDrive/인공지능사관학교/빅데이터/notebook

# %%
# 현 폴더의 위치를 보여준다.
# !pwd        # Linux
# Out:
# /content/drive/MyDrive/인공지능사관학교/빅데이터/notebook

# %%
# 작업 폴더로 이동한다.
# 데이터 파일은 이미 올려져 있어야 한다.
os.chdir("/content/drive/MyDrive/인공지능사관학교/빅데이터/notebook/")

# %%
# 현 폴더의 위치를 보여준다.
# !pwd
# Out:
# /content/drive/My Drive/인공지능사관학교/빅데이터/database

# %%
# 현 폴더의 내용을 보여준다.
# !ls
# Out:
# practice1  practice.db	scratch.db  world.db

# %% [markdown]
# #### 테이블 내용 가져와 보기:

# %%
# SQLite 에 연결 & Cursor 생성.
os.chdir("../database/")
conn = sqlite3.connect("world.db")
cur = conn.cursor()

# %%
# MySQL 행 가져오기.
sql = "SELECT Name, Code, Region, Population FROM Country ORDER BY Population DESC;"
cur.execute(sql);
res = cur.fetchall()

# %%
# 자료형은 List of tuples.
print(type(res))
print(type(res[0]))
# Out:
# <class 'list'>
# <class 'tuple'>

# %%
for x in res:
    print(x)
# Out:
# ('China', 'CHN', 'Eastern Asia', 1277558000)
# ('India', 'IND', 'Southern and Central Asia', 1013662000)
# ('United States', 'USA', 'North America', 278357000)
# ('Indonesia', 'IDN', 'Southeast Asia', 212107000)
# ('Brazil', 'BRA', 'South America', 170115000)
# ('Pakistan', 'PAK', 'Southern and Central Asia', 156483000)
# ('Russian Federation', 'RUS', 'Eastern Europe', 146934000)
# ('Bangladesh', 'BGD', 'Southern and Central Asia', 129155000)
# ('Japan', 'JPN', 'Eastern Asia', 126714000)
# ('Nigeria', 'NGA', 'Western Africa', 111506000)
# ('Mexico', 'MEX', 'Central America', 98881000)
# ('Germany', 'DEU', 'Western Europe', 82164700)
# ('Vietnam', 'VNM', 'Southeast Asia', 79832000)
# ('Philippines', 'PHL', 'Southeast Asia', 75967000)
# ('Egypt', 'EGY', 'Northern Africa', 68470000)
# ('Iran', 'IRN', 'Southern and Central Asia', 67702000)
# ('Turkey', 'TUR', 'Middle East', 66591000)
# ('Ethiopia', 'ETH', 'Eastern Africa', 62565000)
# ('Thailand', 'THA', 'Southeast Asia', 61399000)
# ('United Kingdom', 'GBR', 'British Islands', 59623400)
# ('France', 'FRA', 'Western Europe', 59225700)
# ('Italy', 'ITA', 'Southern Europe', 57680000)
# ('Congo, The Democratic Republic of the', 'COD', 'Central Africa', 51654000)
# ('Ukraine', 'UKR', 'Eastern Europe', 50456000)
# ('South Korea', 'KOR', 'Eastern Asia', 46844000)
# ('Myanmar', 'MMR', 'Southeast Asia', 45611000)
# ('Colombia', 'COL', 'South America', 42321000)
# ('South Africa', 'ZAF', 'Southern Africa', 40377000)
# ('Spain', 'ESP', 'Southern Europe', 39441700)
# ('Poland', 'POL', 'Eastern Europe', 38653600)
# ('Argentina', 'ARG', 'South America', 37032000)
# ('Tanzania', 'TZA', 'Eastern Africa', 33517000)
# ('Algeria', 'DZA', 'Northern Africa', 31471000)
# ('Canada', 'CAN', 'North America', 31147000)
# ('Kenya', 'KEN', 'Eastern Africa', 30080000)
# ('Sudan', 'SDN', 'Northern Africa', 29490000)
# ('Morocco', 'MAR', 'Northern Africa', 28351000)
# ('Peru', 'PER', 'South America', 25662000)
# ('Uzbekistan', 'UZB', 'Southern and Central Asia', 24318000)
# ('Venezuela', 'VEN', 'South America', 24170000)
# ('North Korea', 'PRK', 'Eastern Asia', 24039000)
# ('Nepal', 'NPL', 'Southern and Central Asia', 23930000)
# ('Iraq', 'IRQ', 'Middle East', 23115000)
# ('Afghanistan', 'AFG', 'Southern and Central Asia', 22720000)
# ('Romania', 'ROM', 'Eastern Europe', 22455500)
# ('Taiwan', 'TWN', 'Eastern Asia', 22256000)
# ('Malaysia', 'MYS', 'Southeast Asia', 22244000)
# ('Uganda', 'UGA', 'Eastern Africa', 21778000)
# ('Saudi Arabia', 'SAU', 'Middle East', 21607000)
# ('Ghana', 'GHA', 'Western Africa', 20212000)
# ('Mozambique', 'MOZ', 'Eastern Africa', 19680000)
# ('Australia', 'AUS', 'Australia and New Zealand', 18886000)
# ('Sri Lanka', 'LKA', 'Southern and Central Asia', 18827000)
# ('Yemen', 'YEM', 'Middle East', 18112000)
# ('Kazakstan', 'KAZ', 'Southern and Central Asia', 16223000)
# ('Syria', 'SYR', 'Middle East', 16125000)
# ('Madagascar', 'MDG', 'Eastern Africa', 15942000)
# ('Netherlands', 'NLD', 'Western Europe', 15864000)
# ('Chile', 'CHL', 'South America', 15211000)
# ('Cameroon', 'CMR', 'Central Africa', 15085000)
# ('Côte d’Ivoire', 'CIV', 'Western Africa', 14786000)
# ('Angola', 'AGO', 'Central Africa', 12878000)
# ('Ecuador', 'ECU', 'South America', 12646000)
# ('Burkina Faso', 'BFA', 'Western Africa', 11937000)
# ('Zimbabwe', 'ZWE', 'Eastern Africa', 11669000)
# ('Guatemala', 'GTM', 'Central America', 11385000)
# ('Mali', 'MLI', 'Western Africa', 11234000)
# ('Cuba', 'CUB', 'Caribbean', 11201000)
# ('Cambodia', 'KHM', 'Southeast Asia', 11168000)
# ('Malawi', 'MWI', 'Eastern Africa', 10925000)
# ('Niger', 'NER', 'Western Africa', 10730000)
# ('Yugoslavia', 'YUG', 'Southern Europe', 10640000)
# ('Greece', 'GRC', 'Southern Europe', 10545700)
# ('Czech Republic', 'CZE', 'Eastern Europe', 10278100)
# ('Belgium', 'BEL', 'Western Europe', 10239000)
# ('Belarus', 'BLR', 'Eastern Europe', 10236000)
# ('Somalia', 'SOM', 'Eastern Africa', 10097000)
# ('Hungary', 'HUN', 'Eastern Europe', 10043200)
# ('Portugal', 'PRT', 'Southern Europe', 9997600)
# ('Tunisia', 'TUN', 'Northern Africa', 9586000)
# ('Senegal', 'SEN', 'Western Africa', 9481000)
# ('Zambia', 'ZMB', 'Eastern Africa', 9169000)
# ('Sweden', 'SWE', 'Nordic Countries', 8861400)
# ('Dominican Republic', 'DOM', 'Caribbean', 8495000)
# ('Bolivia', 'BOL', 'South America', 8329000)
# ('Haiti', 'HTI', 'Caribbean', 8222000)
# ('Bulgaria', 'BGR', 'Eastern Europe', 8190900)
# ('Austria', 'AUT', 'Western Europe', 8091800)
# ('Azerbaijan', 'AZE', 'Middle East', 7734000)
# ('Rwanda', 'RWA', 'Eastern Africa', 7733000)
# ('Chad', 'TCD', 'Central Africa', 7651000)
# ('Guinea', 'GIN', 'Western Africa', 7430000)
# ('Switzerland', 'CHE', 'Western Europe', 7160400)
# ('Hong Kong', 'HKG', 'Eastern Asia', 6782000)
# ('Burundi', 'BDI', 'Eastern Africa', 6695000)
# ('Honduras', 'HND', 'Central America', 6485000)
# ('El Salvador', 'SLV', 'Central America', 6276000)
# ('Israel', 'ISR', 'Middle East', 6217000)
# ('Tajikistan', 'TJK', 'Southern and Central Asia', 6188000)
# ('Benin', 'BEN', 'Western Africa', 6097000)
# ('Libyan Arab Jamahiriya', 'LBY', 'Northern Africa', 5605000)
# ('Paraguay', 'PRY', 'South America', 5496000)
# ('Laos', 'LAO', 'Southeast Asia', 5433000)
# ('Slovakia', 'SVK', 'Eastern Europe', 5398700)
# ('Denmark', 'DNK', 'Nordic Countries', 5330000)
# ('Finland', 'FIN', 'Nordic Countries', 5171300)
# ('Jordan', 'JOR', 'Middle East', 5083000)
# ('Nicaragua', 'NIC', 'Central America', 5074000)
# ('Georgia', 'GEO', 'Middle East', 4968000)
# ('Sierra Leone', 'SLE', 'Western Africa', 4854000)
# ('Papua New Guinea', 'PNG', 'Melanesia', 4807000)
# ('Kyrgyzstan', 'KGZ', 'Southern and Central Asia', 4699000)
# ('Togo', 'TGO', 'Western Africa', 4629000)
# ('Norway', 'NOR', 'Nordic Countries', 4478500)
# ('Croatia', 'HRV', 'Southern Europe', 4473000)
# ('Turkmenistan', 'TKM', 'Southern and Central Asia', 4459000)
# ('Moldova', 'MDA', 'Eastern Europe', 4380000)
# ('Costa Rica', 'CRI', 'Central America', 4023000)
# ('Bosnia and Herzegovina', 'BIH', 'Southern Europe', 3972000)
# ('Puerto Rico', 'PRI', 'Caribbean', 3869000)
# ('New Zealand', 'NZL', 'Australia and New Zealand', 3862000)
# ('Eritrea', 'ERI', 'Eastern Africa', 3850000)
# ('Ireland', 'IRL', 'British Islands', 3775100)
# ('Lithuania', 'LTU', 'Baltic Countries', 3698500)
# ('Central African Republic', 'CAF', 'Central Africa', 3615000)
# ('Singapore', 'SGP', 'Southeast Asia', 3567000)
# ('Armenia', 'ARM', 'Middle East', 3520000)
# ('Albania', 'ALB', 'Southern Europe', 3401200)
# ('Uruguay', 'URY', 'South America', 3337000)
# ('Lebanon', 'LBN', 'Middle East', 3282000)
# ('Liberia', 'LBR', 'Western Africa', 3154000)
# ('Palestine', 'PSE', 'Middle East', 3101000)
# ('Congo', 'COG', 'Central Africa', 2943000)
# ('Panama', 'PAN', 'Central America', 2856000)
# ('Mauritania', 'MRT', 'Western Africa', 2670000)
# ('Mongolia', 'MNG', 'Eastern Asia', 2662000)
# ('Jamaica', 'JAM', 'Caribbean', 2583000)
# ('Oman', 'OMN', 'Middle East', 2542000)
# ('United Arab Emirates', 'ARE', 'Middle East', 2441000)
# ('Latvia', 'LVA', 'Baltic Countries', 2424200)
# ('Lesotho', 'LSO', 'Southern Africa', 2153000)
# ('Bhutan', 'BTN', 'Southern and Central Asia', 2124000)
# ('Macedonia', 'MKD', 'Southern Europe', 2024000)
# ('Slovenia', 'SVN', 'Southern Europe', 1987800)
# ('Kuwait', 'KWT', 'Middle East', 1972000)
# ('Namibia', 'NAM', 'Southern Africa', 1726000)
# ('Botswana', 'BWA', 'Southern Africa', 1622000)
# ('Estonia', 'EST', 'Baltic Countries', 1439200)
# ('Gambia', 'GMB', 'Western Africa', 1305000)
# ('Trinidad and Tobago', 'TTO', 'Caribbean', 1295000)
# ('Gabon', 'GAB', 'Central Africa', 1226000)
# ('Guinea-Bissau', 'GNB', 'Western Africa', 1213000)
# ('Mauritius', 'MUS', 'Eastern Africa', 1158000)
# ('Swaziland', 'SWZ', 'Southern Africa', 1008000)
# ('East Timor', 'TMP', 'Southeast Asia', 885000)
# ('Guyana', 'GUY', 'South America', 861000)
# ('Fiji Islands', 'FJI', 'Melanesia', 817000)
# ('Cyprus', 'CYP', 'Middle East', 754700)
# ('Réunion', 'REU', 'Eastern Africa', 699000)
# ('Djibouti', 'DJI', 'Eastern Africa', 638000)
# ('Bahrain', 'BHR', 'Middle East', 617000)
# ('Qatar', 'QAT', 'Middle East', 599000)
# ('Comoros', 'COM', 'Eastern Africa', 578000)
# ('Macao', 'MAC', 'Eastern Asia', 473000)
# ('Guadeloupe', 'GLP', 'Caribbean', 456000)
# ('Equatorial Guinea', 'GNQ', 'Central Africa', 453000)
# ('Solomon Islands', 'SLB', 'Melanesia', 444000)
# ('Luxembourg', 'LUX', 'Western Europe', 435700)
# ('Cape Verde', 'CPV', 'Western Africa', 428000)
# ('Suriname', 'SUR', 'South America', 417000)
# ('Martinique', 'MTQ', 'Caribbean', 395000)
# ('Malta', 'MLT', 'Southern Europe', 380200)
# ('Brunei', 'BRN', 'Southeast Asia', 328000)
# ('Bahamas', 'BHS', 'Caribbean', 307000)
# ('Western Sahara', 'ESH', 'Northern Africa', 293000)
# ('Maldives', 'MDV', 'Southern and Central Asia', 286000)
# ('Iceland', 'ISL', 'Nordic Countries', 279000)
# ('Barbados', 'BRB', 'Caribbean', 270000)
# ('Belize', 'BLZ', 'Central America', 241000)
# ('French Polynesia', 'PYF', 'Polynesia', 235000)
# ('Netherlands Antilles', 'ANT', 'Caribbean', 217000)
# ('New Caledonia', 'NCL', 'Melanesia', 214000)
# ('Vanuatu', 'VUT', 'Melanesia', 190000)
# ('French Guiana', 'GUF', 'South America', 181000)
# ('Samoa', 'WSM', 'Polynesia', 180000)
# ('Guam', 'GUM', 'Micronesia', 168000)
# ('Saint Lucia', 'LCA', 'Caribbean', 154000)
# ('Mayotte', 'MYT', 'Eastern Africa', 149000)
# ('Sao Tome and Principe', 'STP', 'Central Africa', 147000)
# ('Micronesia, Federated States of', 'FSM', 'Micronesia', 119000)
# ('Saint Vincent and the Grenadines', 'VCT', 'Caribbean', 114000)
# ('Aruba', 'ABW', 'Caribbean', 103000)
# ('Tonga', 'TON', 'Polynesia', 99000)
# ('Grenada', 'GRD', 'Caribbean', 94000)
# ('Virgin Islands, U.S.', 'VIR', 'Caribbean', 93000)
# ('Kiribati', 'KIR', 'Micronesia', 83000)
# ('Andorra', 'AND', 'Southern Europe', 78000)
# ('Northern Mariana Islands', 'MNP', 'Micronesia', 78000)
# ('Seychelles', 'SYC', 'Eastern Africa', 77000)
# ('Dominica', 'DMA', 'Caribbean', 71000)
# ('American Samoa', 'ASM', 'Polynesia', 68000)
# ('Antigua and Barbuda', 'ATG', 'Caribbean', 68000)
# ('Bermuda', 'BMU', 'North America', 65000)
# ('Marshall Islands', 'MHL', 'Micronesia', 64000)
# ('Greenland', 'GRL', 'North America', 56000)
# ('Faroe Islands', 'FRO', 'Nordic Countries', 43000)
# ('Cayman Islands', 'CYM', 'Caribbean', 38000)
# ('Saint Kitts and Nevis', 'KNA', 'Caribbean', 38000)
# ('Monaco', 'MCO', 'Western Europe', 34000)
# ('Liechtenstein', 'LIE', 'Western Europe', 32300)
# ('San Marino', 'SMR', 'Southern Europe', 27000)
# ('Gibraltar', 'GIB', 'Southern Europe', 25000)
# ('Virgin Islands, British', 'VGB', 'Caribbean', 21000)
# ('Cook Islands', 'COK', 'Polynesia', 20000)
# ('Palau', 'PLW', 'Micronesia', 19000)
# ('Turks and Caicos Islands', 'TCA', 'Caribbean', 17000)
# ('Wallis and Futuna', 'WLF', 'Polynesia', 15000)
# ('Nauru', 'NRU', 'Micronesia', 12000)
# ('Tuvalu', 'TUV', 'Polynesia', 12000)
# ('Montserrat', 'MSR', 'Caribbean', 11000)
# ('Anguilla', 'AIA', 'Caribbean', 8000)
# ('Saint Pierre and Miquelon', 'SPM', 'North America', 7000)
# ('Saint Helena', 'SHN', 'Western Africa', 6000)
# ('Svalbard and Jan Mayen', 'SJM', 'Nordic Countries', 3200)
# ('Christmas Island', 'CXR', 'Australia and New Zealand', 2500)
# ('Falkland Islands', 'FLK', 'South America', 2000)
# ('Norfolk Island', 'NFK', 'Australia and New Zealand', 2000)
# ('Niue', 'NIU', 'Polynesia', 2000)
# ('Tokelau', 'TKL', 'Polynesia', 2000)
# ('Holy See (Vatican City State)', 'VAT', 'Southern Europe', 1000)
# ('Cocos (Keeling) Islands', 'CCK', 'Australia and New Zealand', 600)
# ('Pitcairn', 'PCN', 'Polynesia', 50)
# ('Antarctica', 'ATA', 'Antarctica', None)
# ('French Southern territories', 'ATF', 'Antarctica', None)
# ('Bouvet Island', 'BVT', 'Antarctica', None)
# ('Heard Island and McDonald Islands', 'HMD', 'Antarctica', None)
# ('British Indian Ocean Territory', 'IOT', 'Eastern Africa', None)
# ('South Georgia and the South Sandwich Islands', 'SGS', 'Antarctica', None)
# ('United States Minor Outlying Islands', 'UMI', 'Micronesia/Caribbean', None)

# %%
conn.close()

# %% [markdown]
# #### 테이블 생성, 행 삽입, 출력, 테이블 삭제:

# %%
# SQLite 에 연결 & Cursor 생성.
os.chdir("../database")
conn = sqlite3.connect("scratch.db")
cur = conn.cursor()

# %%
# MySQL 테이블 생성.
sql = "CREATE TABLE IF NOT EXISTS test ( a INT, b TEXT, c TEXT );"
cur.execute(sql);
conn.commit();

# %%
# "test" 테이블에 행 추가.
sql = "INSERT INTO test VALUES ( ?, ?, ? );"      # ?를 placeholder로 사용!
x = [1, "Hello", "World"]                        # 삽입될 내용.
cur.execute(sql,x);                                # 실행!
conn.commit();

# %%
# "test" 테이블에 행 계속 추가.
sqls = ["INSERT INTO test VALUES ( 2, 'This', 'Right here!' );", 
        "INSERT INTO test ( b, c ) VALUES ( 'That', 'Over there!' );",
        "INSERT INTO test ( a, b, c ) SELECT id, name, description FROM item;"] 
for a_sql in sqls:
    cur.execute(a_sql);
    conn.commit();

# %%
# 테이블 내용 보기.
sql = "SELECT * FROM test"
cur.execute(sql);
res = cur.fetchall()
for x in res:
    print(x)
# Out:
# (1, 'Hello', 'World')
# (2, 'This', 'Right here!')
# (None, 'That', 'Over there!')
# (1, 'Box of 64 Pixels', '64 RGB pixels in a decorative box')
# (2, 'Sense of Humor', 'Especially dry. Imported from England.')
# (3, 'Beauty', 'Inner beauty. No cosmetic surgery required!')
# (4, 'Bar Code', 'Unused. In original packaging.')

# %%
sql = "DROP TABLE test;"
cur.execute(sql);
conn.commit()

# %%
conn.close()
